# %% [markdown]
# # Pre-processing

# %% [markdown]
# ## Garbage in garbage out!
# Prepearing the data to the classification task by taking care of:
# - Missing values
# - Outliers
# - Inconsistencies
# - Normalization
# - Discretization <br>
# and more

# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
sns.set(color_codes=True) 
sns.set(rc={'figure.figsize':(5,5)})

# %%
df = pd.read_csv("./data-tergul3/titanic.csv")
df['Fare'] = df['Fare'].str.extract('(\d+\.?\d*)', expand = True).astype(float)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_csv("./data-tergul3/titanic.csv")
#       2 df['Fare'] = df['Fare'].str.extract('(\d+\.?\d*)', expand = True).astype(float)
#       3 df.head()
#
# File c:\Users\amiri\anaconda3\envs\DataMiningEnviorment\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\amiri\anaconda3\envs\DataMiningEnviorment\lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\amiri\anaconda3\envs\DataMiningEnviorment\lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\amiri\anaconda3\envs\DataMiningEnviorment\lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\amiri\anaconda3\envs\DataMiningEnviorment\lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './data-tergul3/titanic.csv'

# %% [markdown]
# ## Missing values
# In order to decide how to handle the missing values for a specific attribute, we should consider the following:
# - Are the values continuous or categorical?
# - How many objects are missing?
# - The attribute distribution
# - The relations between attributes
# - The relations between objects
#
# The decisions we can make:
# - Completing the missing values
# - Deleting the row with the missing values
# - Deleting the column with the missing values
# - Do nothing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# The columns with missing values are 'Age', 'Cabin' and 'Embarked'. We will take care each one of them separately and differently.<br>
# Before dealing with each attribute, we will check if there are rows with too much missing data.

# %%
df[df.isnull().sum(axis=1)>1]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex  Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 5      male  NaN      0      0      330877   8.46   NaN        Q
# 17     male  NaN      0      0      244373  13.00   NaN        S
# 19   female  NaN      0      0        2649   7.23   NaN        C
# 26     male  NaN      0      0        2631   7.23   NaN        C
# 28   female  NaN      0      0      330959   7.88   NaN        Q
# ..      ...  ...    ...    ...         ...    ...   ...      ...
# 859    male  NaN      0      0        2629   7.23   NaN        C
# 863  female  NaN      8      2    CA. 2343  69.55   NaN        S
# 868    male  NaN      0      0      345777   9.50   NaN        S
# 878    male  NaN      0      0      349217   7.90   NaN        S
# 888  female  NaN      1      2  W./C. 6607  23.45   NaN        S
#
# [158 rows x 12 columns]

# %%
df[df['Embarked'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %% [markdown]
# ### Embarked
# This is a categorical feature and it only has two missing values.

# %%
sns.catplot(x = 'Embarked', kind = 'count', data = df)

# %%
df['Embarked'].value_counts()['S']/df.shape[0]
# Out:
# 0.7227833894500562

# %% [markdown]
# Since both of the missing values are for females we can check if there is a difference for females.

# %%
female_df = df[df['Sex']=='female']
sns.catplot(x = 'Embarked', kind = 'count', data = female_df)

# %% [markdown]
# 72% of the values are 'S' and as we saw there are only two missing values hence, we can complete them with the mode - 'S'.

# %%
mode = df['Embarked'].mode()[0]
mode
# Out:
# 'S'

# %%
df['Embarked'] = df['Embarked'].fillna(mode)

# %%
df[df['Embarked'].isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# ### Cabin

# %% [markdown]
# This is a categorical attribute and it has a lot of missing values and unique values.

# %%
print('Number of missing values: ', df.shape[0] - df['Cabin'].isnull().sum())
print('Number of unique values: ', df['Cabin'].unique().shape[0])
# Out:
# Number of missing values:  204
# Number of unique values:  148

# %%
df['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
#        'E58', 'C126', 'B71', 'B51 B53 B55', 'D49', 'B5', 'B20', 'F G63',
#        'C62 C64', 'E24', 'C90', 'C45', 'E8', 'B101', 'D45', 'C46', 'D30',
#        'E121', 'D11', 'E77', 'F38', 'B3', 'D6', 'B82 B84', 'D17', 'A36',
#        'B102', 'B69', 'E49', 'C47', 'D28', 'E17', 'A24', 'C50', 'B42',
#        'C148'], dtype=object)

# %% [markdown]
# As we can see, the values consist of letters and numbers that represent the deck and the room number. In addition, there are passengers with more than one cabin but they are on the same deck.

# %%
df['Cabin'] = df['Cabin'].fillna('Missing') # To see the missing value in the analysis
df['Deck'] = df['Cabin'].str[0]
df['Deck'].value_counts()
# Out:
# Deck
# M    687
# C     59
# B     47
# D     33
# E     32
# A     15
# F     13
# G      4
# T      1
# Name: count, dtype: int64

# %% [markdown]
# Is 'T' an outlier?

# %%
df[df['Deck']=='T']
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 339          340         0       1  Blackwell, Mr. Stephen Weart  male  45.0
#
#      SibSp  Parch  Ticket  Fare Cabin Embarked Deck
# 339      0      0  113784  35.5     T        S    T

# %%
df.loc[df['Deck']=='T', 'Deck'] = 'M'
df['Deck'].value_counts()
# Out:
# Deck
# M    688
# C     59
# B     47
# D     33
# E     32
# A     15
# F     13
# G      4
# Name: count, dtype: int64

# %% [markdown]
# ### Age
# Since this attribute is continuous, several methods can be applied to complete the values.

# %% [markdown]
# ##### 1. Filling missing values by median/mean.

# %%
df['Age_1'] = df['Age'].fillna(value=df['Age'].median())

# %% [markdown]
# ##### 2. Filling missing values by exploring correlations.

# %% [markdown]
# Categorical data should be adjusted before calculating the correlation.

# %%
df['Sex_cat'] = df['Sex'].astype('category').cat.codes
df['Embarked_cat'] = df['Embarked'].astype('category').cat.codes

# %%
df['Deck_cat'] = df['Deck'].astype('category').cat.codes

# %%
df.groupby(['Sex','Sex_cat']).size()
# Out:
# Sex     Sex_cat
# female  0          314
# male    1          577
# dtype: int64

# %%
df[df.describe().columns].corr(method = 'pearson')
# Out:
#               PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId      1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived        -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass          -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age              0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp           -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch           -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare             0.012659  0.257303 -0.549490  0.096062  0.159654  0.216228
# Age_1            0.034212 -0.064910 -0.339898  1.000000 -0.233296 -0.172482
# Sex_cat          0.042939 -0.543351  0.131900  0.093254 -0.114631 -0.245489
# Embarked_cat     0.013128 -0.167675  0.162098 -0.030394  0.068230  0.039798
# Deck_cat        -0.032869 -0.294804  0.743251 -0.267987  0.041333 -0.031308
#
#                   Fare     Age_1   Sex_cat  Embarked_cat  Deck_cat
# PassengerId   0.012659  0.034212  0.042939      0.013128 -0.032869
# Survived      0.257303 -0.064910 -0.543351     -0.167675 -0.294804
# Pclass       -0.549490 -0.339898  0.131900      0.162098  0.743251
# Age           0.096062  1.000000  0.093254     -0.030394 -0.267987
# SibSp         0.159654 -0.233296 -0.114631      0.068230  0.041333
# Parch         0.216228 -0.172482 -0.245489      0.039798 -0.031308
# Fare          1.000000  0.096684 -0.182330     -0.224719 -0.525989
# Age_1         0.096684  1.000000  0.081163     -0.018754 -0.256312
# Sex_cat      -0.182330  0.081163  1.000000      0.108262  0.118282
# Embarked_cat -0.224719 -0.018754  0.108262      1.000000  0.199207
# Deck_cat     -0.525989 -0.256312  0.118282      0.199207  1.000000

# %% [markdown]
# Visualization of the correlation matrix

# %%
f, ax = plt.subplots(figsize=(10, 7))
ax = sns.heatmap(df[df.describe().columns].corr(), annot = True, vmin=-1, vmax=1, center= 0,
            cmap= 'coolwarm', linewidths=0.2, linecolor='black')

# %% [markdown]
# There is a correlation with 'Pclass', therefore it is an option to divide into three groups conforming to this attribute, and in each group complete the value according to the median/mean.

# %%
g = sns.FacetGrid(df, col="Pclass")
g.map_dataframe(sns.histplot, x="Age", bins=20)

# %%
for i in sorted(df['Pclass'].unique()):
    print('For class ', i, ' the median is ', df.loc[df['Pclass']==i , 'Age'].median())
    print('For class ', i, ' the mesn is ', df.loc[df['Pclass']==i , 'Age'].mean())
    print('and the number of missing values is ', df.loc[df['Pclass']==i , 'Age'].isnull().sum(), 
          'out of ',(df['Pclass']==i).sum(), 'rows')
# Out:
# For class  1  the median is  37.0
# For class  1  the mesn is  38.233440860215055
# and the number of missing values is  30 out of  216 rows
# For class  2  the median is  29.0
# For class  2  the mesn is  29.87763005780347
# and the number of missing values is  11 out of  184 rows
# For class  3  the median is  24.0
# For class  3  the mesn is  25.14061971830986
# and the number of missing values is  136 out of  491 rows

# %% [markdown]
# In class 3 there are too many missing values hence we will handle them differently.

# %%
df['Age_2'] = df['Age']
for i in [1,2]:
    df.loc[df['Pclass']==i , 'Age_2'] = df['Age_2'][df['Pclass']==i].fillna(value=df['Age'][df['Pclass']==i].median())

# %% [markdown]
# For class 3 we will generate random values from a similar distribution.

# %%
mu = df.loc[df['Pclass']==3 , 'Age_2'].mean()
sigma = df.loc[df['Pclass']==3 , 'Age_2'].std()
[mu , sigma]
# Out:
# [25.14061971830986, 12.495398210982415]

# %%
def fill_missing_age(row):
    if pd.isna(row['Age_2']) and row['Pclass'] == 3:
        return np.random.normal(mu, sigma)
    else:
        return row['Age_2']

df['Age_2'] = df.apply(fill_missing_age, axis=1)

# %%
df[df['Pclass']==3]['Age_2']
# Out:
# 0      22.000000
# 2      26.000000
# 4      35.000000
# 5      42.036231
# 7       2.000000
#          ...
# 882    22.000000
# 884    25.000000
# 885    39.000000
# 888    39.537983
# 890    32.000000
# Name: Age_2, Length: 491, dtype: float64

# %%
g = sns.FacetGrid(df, col="Pclass")
g.map_dataframe(sns.histplot, x="Age_2", bins=20)

# %%
g = sns.FacetGrid(df, col="Pclass")
g.map_dataframe(sns.histplot, x="Age", bins=20)

# %% [markdown]
# #### Save the data with the pre-process we did

# %%
df.to_csv('Titanic_3.csv')
